# %%
from model import Model
from autoencoder import Autoencoder
import torch.nn as nn
import torch.optim as optim
from simulator import Simulator

# %%
size_figure = 28
type_psf = 'psf_gauss_'+str(size_figure)+'x'+str(size_figure)
num_epochs= 2
learning_rate = 1e-3 
batch_train = 2
start = 0 
stop = 100
step = 10
criterion = nn.MSELoss() ## definir si esto va a variar o fijarlo! 
net = Autoencoder()  
optimizer = optim.Adam(net.parameters(), lr=learning_rate) ### QUIZAS NO ES UN PARAMETRo DE ENTRADA! 

model_1 = Model(size_figure = size_figure,
                type_psf = type_psf,
                num_epochs = num_epochs,
                learning_rate =  learning_rate , 
                batch_train = batch_train ,
                start = start,
                stop = stop,
                criterion = criterion,
                optimizer = optimizer
               )

# %%
model_1.run_data(net = net,start = 0 , stop = 100)
# Out:
# ...
# 100%|██████████| 35/35 [00:00<00:00, 220.16it/s]
# Epoch 1 of 2, Train Loss: 0.110, Len Train:35
# Epoch 1 of 2, Validate Loss: 0.067 Len Validate:10
# Epoch 2 of 2, Train Loss: 0.054, Len Train:35
# Epoch 2 of 2, Validate Loss: 0.027 Len Validate:10
# 100%|██████████| 10/10 [00:00<00:00, 366.44it/s]
#  Len test:10
# Autoencoder(
#   (enc1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc3): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc4): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dec1): ConvTranspose2d(8, 8, kernel_size=(3, 3), stride=(2, 2))
#   (dec2): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(2, 2))
#   (dec3): ConvTranspose2d(16, 32, kernel_size=(2, 2), stride=(2, 2))
# ...

# %%
model_1.get_resumen(net= net)
# Out:
# Image size: 28
# Len dataset: 100
# Type psf: psf_gauss_28x28
# Number epoch: 2
# Learning rate: 0.001
# Batch train: 2
#
#
# Net:  Autoencoder(
#   (enc1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc3): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc4): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dec1): ConvTranspose2d(8, 8, kernel_size=(3, 3), stride=(2, 2))
#   (dec2): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(2, 2))
#   (dec3): ConvTranspose2d(16, 32, kernel_size=(2, 2), stride=(2, 2))
#   (dec4): ConvTranspose2d(32, 64, kernel_size=(2, 2), stride=(2, 2))
#   (out): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )

# %%
size_figure = 28
type_psf = 'psf_gauss_'+str(size_figure)+'x'+str(size_figure)
num_epochs= 2
learning_rate = 1e-3 
batch_train = 2
start = 0 
stop = 100
step = 10
criterion = nn.MSELoss() ## definir si esto va a variar o fijarlo! 
net = Autoencoder()  
optimizer = optim.Adam(net.parameters(), lr=learning_rate) ### QUIZAS NO ES UN PARAMETRo DE ENTRADA! 

model_2 = Model(size_figure = size_figure,
                type_psf = type_psf,
                num_epochs = num_epochs,
                learning_rate =  learning_rate , 
                batch_train = batch_train ,
                start = start,
                stop = stop,
                criterion = criterion,
                optimizer = optimizer
               )

# %%
model_2.run_data_memory(net = net,start = 0 , stop = 100,step= 100)
# Out:
# 100%|██████████| 35/35 [00:00<00:00, 183.22it/s]
# Epoch 1 of 2, Train Loss: 0.100, Len Train:35
# Epoch 1 of 2, Validate Loss: 0.040 Len Validate:10
# 100%|██████████| 35/35 [00:00<00:00, 165.78it/s]
# Epoch 2 of 2, Train Loss: 0.049, Len Train:35
# Epoch 2 of 2, Validate Loss: 0.018 Len Validate:10
# 100%|██████████| 10/10 [00:00<00:00, 374.90it/s]
#  Len test:10
# Autoencoder(
#   (enc1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc3): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc4): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dec1): ConvTranspose2d(8, 8, kernel_size=(3, 3), stride=(2, 2))
#   (dec2): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(2, 2))
#   (dec3): ConvTranspose2d(16, 32, kernel_size=(2, 2), stride=(2, 2))
# ...

# %%
model_2.get_resumen(net= net)
# Out:
# Image size: 28
# Len dataset: 100
# Type psf: psf_gauss_28x28
# Number epoch: 2
# Learning rate: 0.001
# Batch train: 2
#
#
# Net:  Autoencoder(
#   (enc1): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc2): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc3): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (enc4): Conv2d(16, 8, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (dec1): ConvTranspose2d(8, 8, kernel_size=(3, 3), stride=(2, 2))
#   (dec2): ConvTranspose2d(8, 16, kernel_size=(3, 3), stride=(2, 2))
#   (dec3): ConvTranspose2d(16, 32, kernel_size=(2, 2), stride=(2, 2))
#   (dec4): ConvTranspose2d(32, 64, kernel_size=(2, 2), stride=(2, 2))
#   (out): Conv2d(64, 1, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
# )
